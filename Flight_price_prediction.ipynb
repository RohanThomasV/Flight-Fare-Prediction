# %%
import sklearn
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
Data=pd.read_excel('Data_Train.xlsx')
Data['Destination'].value_counts()
# Out:
# Destination
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: count, dtype: int64

# %%
Data['Destination']=l.fit_transform(Data['Destination'])

# %%
Data['Total_Stops'].value_counts()
# Out:
# Total_Stops
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: count, dtype: int64

# %%
Data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
Data=Data.drop(['Additional_Info'],axis=1)

# %%
Data=Data.drop(['Route'],axis=1)

# %%
Data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Price              0
# dtype: int64

# %%
Data.head()
# Out:
#        Airline Date_of_Journey    Source Destination Dep_Time  Arrival_Time  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi    22:20  01:10 22 Mar
# 1    Air India       1/05/2019   Kolkata    Banglore    05:50         13:15
# 2  Jet Airways       9/06/2019     Delhi      Cochin    09:25  04:25 10 Jun
# 3       IndiGo      12/05/2019   Kolkata    Banglore    18:05         23:30
# 4       IndiGo      01/03/2019  Banglore   New Delhi    16:50         21:35
#
#   Duration Total_Stops  Price
# 0   2h 50m    non-stop   3897
# 1   7h 25m     2 stops   7662
# 2      19h     2 stops  13882
# 3   5h 25m      1 stop   6218
# 4   4h 45m      1 stop  13302

# %%
pd.set_option('display.max_columns',None)

# %%
Data.head()
# Out:
#        Airline Date_of_Journey    Source Destination Dep_Time  Arrival_Time  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi    22:20  01:10 22 Mar
# 1    Air India       1/05/2019   Kolkata    Banglore    05:50         13:15
# 2  Jet Airways       9/06/2019     Delhi      Cochin    09:25  04:25 10 Jun
# 3       IndiGo      12/05/2019   Kolkata    Banglore    18:05         23:30
# 4       IndiGo      01/03/2019  Banglore   New Delhi    16:50         21:35
#
#   Duration Total_Stops  Price
# 0   2h 50m    non-stop   3897
# 1   7h 25m     2 stops   7662
# 2      19h     2 stops  13882
# 3   5h 25m      1 stop   6218
# 4   4h 45m      1 stop  13302

# %%
Data["Dep_Hour"]=pd.to_datetime(Data["Dep_Time"]).dt.hour
Data["Dep_min"]=pd.to_datetime(Data["Dep_Time"]).dt.minute
# Out:
# C:\Users\Rohan TV\AppData\Local\Temp\ipykernel_31404\2886756111.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Data["Dep_Hour"]=pd.to_datetime(Data["Dep_Time"]).dt.hour
# C:\Users\Rohan TV\AppData\Local\Temp\ipykernel_31404\2886756111.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Data["Dep_min"]=pd.to_datetime(Data["Dep_Time"]).dt.minute

# %%
Data["Journey_day"]=pd.to_datetime(Data["Date_of_Journey"],format="%d/%m/%y").dt.day
Data["Journey_month"]=pd.to_datetime(Data["Date_of_Journey"],format="%d/%m/%y").dt.month
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 Data["Journey_day"]=pd.to_datetime(Data["Date_of_Journey"],format="%d/%m/%y").dt.day
#       2 Data["Journey_month"]=pd.to_datetime(Data["Date_of_Journey"],format="%d/%m/%y").dt.month
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# ...

# %%
Data[['Journey_Day','Journey_Month','Year']]=Data['Date_of_Journey'].str.split('/',expand=True)

# %%
Data['Dur_Hours'] = Data['Duration'].str.extract(r'(\d+)h', expand=False).fillna(0).astype(int)
Data['Dur_Minutes'] = Data['Duration'].str.extract(r'(\d+)m', expand=False).fillna(0).astype(int)

# %%
Data['Arrival_Hour'] = Data['Arrival_Time'].str[:2].astype(int)
Data['Arrival_Minute'] = Data['Arrival_Time'].str[3:5].astype(int)
Data['Arrival_Day'] = Data['Arrival_Time'].str[6:8].fillna(0).astype(int,errors='ignore')
Data['Arrival_Month'] = Data['Arrival_Time'].str[9:12].fillna(0).astype(int,errors='ignore')

# %%
Data
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi    22:20
# 1        Air India       1/05/2019   Kolkata    Banglore    05:50
# 2      Jet Airways       9/06/2019     Delhi      Cochin    09:25
# 3           IndiGo      12/05/2019   Kolkata    Banglore    18:05
# 4           IndiGo      01/03/2019  Banglore   New Delhi    16:50
# ...            ...             ...       ...         ...      ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore    19:55
# 10679    Air India      27/04/2019   Kolkata    Banglore    20:45
# 10680  Jet Airways      27/04/2019  Banglore       Delhi    08:20
# 10681      Vistara      01/03/2019  Banglore   New Delhi    11:30
# 10682    Air India       9/05/2019     Delhi      Cochin    10:55
#
#        Arrival_Time Duration Total_Stops  Price  Dep_Hour  Dep_min  \
# 0      01:10 22 Mar   2h 50m    non-stop   3897        22       20
# ...

# %%
Data=Data.fillna(method='ffill')
# Out:
# C:\Users\Rohan TV\AppData\Local\Temp\ipykernel_31404\3759669059.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Data=Data.fillna(method='ffill')

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Dep_Time         10683 non-null  object
#  5   Arrival_Time     10683 non-null  object
#  6   Duration         10683 non-null  object
#  7   Total_Stops      10683 non-null  object
#  8   Price            10683 non-null  int64
#  9   Dep_Hour         10683 non-null  int32
#  10  Dep_min          10683 non-null  int32
#  11  Journey_Day      10683 non-null  object
#  12  Journey_Month    10683 non-null  object
#  13  Year             10683 non-null  object
#  14  Dur_Hours        10683 non-null  int32
#  15  Dur_Minutes      10683 non-null  int32
#  16  Arrival_Hour     10683 non-null  int32
# ...

# %%
Data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Price              0
# Dep_Hour           0
# Dep_min            0
# Journey_Day        0
# Journey_Month      0
# Year               0
# Dur_Hours          0
# Dur_Minutes        0
# Arrival_Hour       0
# Arrival_Minute     0
# Arrival_Day        0
# Arrival_Month      0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
#Data['Airline']=l.fit_transform(Data['Airline'])

Data['Source']=l.fit_transform(Data['Source'])
Data['Destination']=l.fit_transform(Data['Destination'])
Data['Total_Stops']=l.fit_transform(Data['Total_Stops'])
Data['Arriva']=l.fit_transform(Data['Total_Stops'])

# %%
Data.drop(["Date_of_Journey"],axis=1,inplace=True)

# %%
Data.drop(["Duration"],axis=1,inplace=True)

# %%
Data
# Out:
#            Airline  Source  Destination Dep_Time  Arrival_Time  Total_Stops  \
# 0           IndiGo       0            5    22:20  01:10 22 Mar            4
# 1        Air India       3            0    05:50         13:15            1
# 2      Jet Airways       2            1    09:25  04:25 10 Jun            1
# 3           IndiGo       3            0    18:05         23:30            0
# 4           IndiGo       0            5    16:50         21:35            0
# ...            ...     ...          ...      ...           ...          ...
# 10678     Air Asia       3            0    19:55         22:25            4
# 10679    Air India       3            0    20:45         23:20            4
# 10680  Jet Airways       0            2    08:20         11:20            4
# 10681      Vistara       0            5    11:30         14:10            4
# 10682    Air India       2            1    10:55         19:15            1
#
# ...

# %%
Data.drop(["Duration"],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 Data.drop(["Duration"],axis=1,inplace=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %%
Data.Total_Stops.value_counts()
# Out:
# Total_Stops
# 0    5625
# 4    3492
# 1    1520
# 2      45
# 3       1
# Name: count, dtype: int64

# %%
Data.Total_Stops.replace({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4},inplace=True)
# Out:
# C:\Users\Rohan TV\AppData\Local\Temp\ipykernel_16184\3569092203.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Data.Total_Stops.replace({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4},inplace=True)

# %%
Data.drop(["Year"],axis=1,inplace=True)

# %%
Data.drop(["Dep_Time"],axis=1,inplace=True)

# %%
Data
# Out:
#            Airline  Source  Destination  Arrival_Time  Total_Stops  Price  \
# 0           IndiGo       0            5  01:10 22 Mar            4   3897
# 1        Air India       3            0         13:15            1   7662
# 2      Jet Airways       2            1  04:25 10 Jun            1  13882
# 3           IndiGo       3            0         23:30            0   6218
# 4           IndiGo       0            5         21:35            0  13302
# ...            ...     ...          ...           ...          ...    ...
# 10678     Air Asia       3            0         22:25            4   4107
# 10679    Air India       3            0         23:20            4   4145
# 10680  Jet Airways       0            2         11:20            4   7229
# 10681      Vistara       0            5         14:10            4  12648
# 10682    Air India       2            1         19:15            1  11753
#
#        Dep_Hour  Dep_min Journey_Day Journey_Month  Dur_Hours  Dur_Minutes  \
# ...

# %%
Data=Data.drop(['Arrival_Time'],axis=1)

# %%
Data.drop(["Arrival_Day"],axis=1,inplace=True)

# %%
Data.drop(["Arrival_Month"],axis=1,inplace=True)

# %%
Data.drop(["Arriva"],axis=1,inplace=True)

# %%
null_rows = Data[Data.isnull().any(axis=1)]

print(null_rows)
# Out:
# Empty DataFrame
# Columns: [Airline, Source, Destination, Total_Stops, Price, Dep_Hour, Dep_min, Journey_Day, Journey_Month, Dur_Hours, Dur_Minutes, Arrival_Hour, Arrival_Minute]
# Index: []

# %%
Data.Airline.value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %%
#Data=Data.drop(Data[Data['Airline']=='Multiple carriers Premium economy'].index)

# %%
#airline_c=Data['Airline'].value_counts()

#airline_count_less_10=airline_c[airline_c<=479]
#Data['airline']=Data['Airline'].apply(lambda x: 'other' if x in airline_count_less_10 else x)

#airline_count_less_10

# %%
#Data.Airline.value_counts()

# %%
Data
# Out:
#            Airline  Source  Destination  Total_Stops  Price  Dep_Hour  \
# 0           IndiGo       0            5            4   3897        22
# 1        Air India       3            0            1   7662         5
# 2      Jet Airways       2            1            1  13882         9
# 3           IndiGo       3            0            0   6218        18
# 4           IndiGo       0            5            0  13302        16
# ...            ...     ...          ...          ...    ...       ...
# 10678     Air Asia       3            0            4   4107        19
# 10679    Air India       3            0            4   4145        20
# 10680  Jet Airways       0            2            4   7229         8
# 10681      Vistara       0            5            4  12648        11
# 10682    Air India       2            1            1  11753        10
#
#        Dep_min Journey_Day Journey_Month  Dur_Hours  Dur_Minutes  \
# ...

# %%
Data
# Out:
#            Airline  Source  Destination  Total_Stops  Price  Dep_Hour  \
# 0           IndiGo       0            5            4   3897        22
# 1        Air India       3            0            1   7662         5
# 2      Jet Airways       2            1            1  13882         9
# 3           IndiGo       3            0            0   6218        18
# 4           IndiGo       0            5            0  13302        16
# ...            ...     ...          ...          ...    ...       ...
# 10678     Air Asia       3            0            4   4107        19
# 10679    Air India       3            0            4   4145        20
# 10680  Jet Airways       0            2            4   7229         8
# 10681      Vistara       0            5            4  12648        11
# 10682    Air India       2            1            1  11753        10
#
#        Dep_min Journey_Day Journey_Month  Dur_Hours  Dur_Minutes  \
# ...

# %%
Data['Airline']=l.fit_transform(Data['Airline'])

# %%
Data.Airline.value_counts()
# Out:
# Airline
# Jet Airways          3849
# IndiGo               2053
# Air India            1752
# Multiple carriers    1196
# other                1015
# SpiceJet              818
# Name: count, dtype: int64

# %%
airline_c=Data['Airline'].value_counts()

airline_count_less_10=airline_c[airline_c<=479]
Data['Airline']=Data['Airline'].apply(lambda x: 'other' if x in airline_count_less_10 else x)

airline_count_less_10
# Out:
# Airline
# Vistara                              479
# Air Asia                             319
# GoAir                                194
# Multiple carriers Premium economy     13
# Jet Airways Business                   6
# Vistara Premium economy                3
# Trujet                                 1
# Name: count, dtype: int64

# %%
y=Data[['Price']]
y
# Out:
#        Price
# 0       3897
# 1       7662
# 2      13882
# 3       6218
# 4      13302
# ...      ...
# 10678   4107
# 10679   4145
# 10680   7229
# 10681  12648
# 10682  11753
#
# [10683 rows x 1 columns]

# %%
x=Data.drop(['Price'],axis=1)

# %%
x
# Out:
#        Airline  Source  Destination  Total_Stops  Dep_Hour  Dep_min  \
# 0            1       0            5            4        22       20
# 1            0       3            0            1         5       50
# 2            2       2            1            1         9       25
# 3            1       3            0            0        18        5
# 4            1       0            5            0        16       50
# ...        ...     ...          ...          ...       ...      ...
# 10678        5       3            0            4        19       55
# 10679        0       3            0            4        20       45
# 10680        2       0            2            4         8       20
# 10681        5       0            5            4        11       30
# 10682        0       2            1            1        10       55
#
#       Journey_Day Journey_Month  Dur_Hours  Dur_Minutes  Arrival_Hour  \
# 0              24            03          2           50             1
# ...

# %%
y
# Out:
#        Price
# 0       3897
# 1       7662
# 2      13882
# 3       6218
# 4      13302
# ...      ...
# 10678   4107
# 10679   4145
# 10680   7229
# 10681  12648
# 10682  11753
#
# [10683 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.2)

# %%
len(xtrain),len(xtest),len(ytrain),len(ytest)
# Out:
# (8546, 2137, 8546, 2137)

# %%
xtrain.shape,xtest.shape,ytrain.shape,ytest.shape
# Out:
# ((8546, 12), (2137, 12), (8546, 1), (2137, 1))

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
model.predict(xtest)
# Out:
# array([[14571.18478895],
#        [11616.21470932],
#        [10475.04393056],
#        ...,
#        [ 9344.98838796],
#        [10199.79178425],
#        [ 5463.01738262]])

# %%
model.score(xtest,ytest)
# Out:
# 0.39178875382973843

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()

# %%
model.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor()

# %%
model.predict(xtest)
# Out:
# array([11003. , 15916.5,  8665. , ..., 15544. , 12937. ,  4405. ])

# %%
model.score(xtest,ytest)
# Out:
# 0.5803679029429741

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor()

# %%
model.fit(xtrain,ytrain)
# Out:
# C:\Users\Rohan TV\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
model.predict(xtest)
# Out:
# array([12165.515     , 15797.2725    ,  9333.93      , ...,
#        15619.53333333, 13373.06      ,  4538.12      ])

# %%
model.score(xtest,ytest)
# Out:
# 0.737890348531941

# %%
from sklearn.svm import SVR
model=SVR()

# %%
model.fit(xtrain,ytrain)
# Out:
# C:\Users\Rohan TV\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
model.predict(xtest)
# Out:
# array([8524.39177185, 8532.8256957 , 8058.0324098 , ..., 8413.80846263,
#        8438.61261286, 8023.96838621])

# %%
model.score(xtest,ytest)
# Out:
# 0.002523337958277083

# %%
import pickle

# %%
a=a=open("flight_price_prediction.pkl","wb")
pickle.dump(model,a)

# %%
b=pickle.load(open("flight_price_prediction.pkl","rb"))

# %%
b
# Out:
# RandomForestRegressor()

# %%
b.predict([[1,0,5,1,5,00,5,9,None,None,None,None]])
# Out:
# C:\Users\Rohan TV\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([13371.815])

# %%
x["Airline"].value_counts()
# Out:
# Airline
# 2    3849
# 1    2053
# 0    1752
# 3    1196
# 5    1015
# 4     818
# Name: count, dtype: int64

# %%
Data["Airline"].value_counts()
# Out:
# Airline
# 2    3849
# 1    2053
# 0    1752
# 3    1196
# 5    1015
# 4     818
# Name: count, dtype: int64

# %%
l.transform(Data['Airline'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_encode.py:225, in _encode(values, uniques, check_unknown)
#     224 try:
# --> 225     return _map_to_integer(values, uniques)
#     226 except KeyError as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_encode.py:165, in _map_to_integer(values, uniques)
#     164 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 165 return np.array([table[v] for v in values])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_encode.py:165, in <listcomp>(.0)
# ...
